# %%
import pandas as pd

# %%
df=pd.read_csv("../data/raw data/car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df['Selling_Price']=df['Selling_Price']*100000
df['Present_Price']=df['Present_Price']*100000
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014       335000.0       559000.0       27000    Petrol
# 1      sx4  2013       475000.0       954000.0       43000    Diesel
# 2     ciaz  2017       725000.0       985000.0        6900    Petrol
# 3  wagon r  2011       285000.0       415000.0        5200    Petrol
# 4    swift  2014       460000.0       687000.0       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
from datetime import date
  
# creating the date object of today's date
todays_date = date.today()
print(todays_date)

df["Car_Age"]=todays_date.year-df['Year']
df.head()
# Out:
# 2025-09-08
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014       335000.0       559000.0       27000    Petrol
# 1      sx4  2013       475000.0       954000.0       43000    Diesel
# 2     ciaz  2017       725000.0       985000.0        6900    Petrol
# 3  wagon r  2011       285000.0       415000.0        5200    Petrol
# 4    swift  2014       460000.0       687000.0       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age
# 0      Dealer       Manual      0       11
# 1      Dealer       Manual      0       12
# 2      Dealer       Manual      0        8
# 3      Dealer       Manual      0       14
# 4      Dealer       Manual      0       11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       201 non-null    object
#  1   Year           201 non-null    int64
#  2   Selling_Price  201 non-null    float64
#  3   Present_Price  201 non-null    float64
#  4   Kms_Driven     201 non-null    int64
#  5   Fuel_Type      201 non-null    object
#  6   Seller_Type    201 non-null    object
#  7   Transmission   201 non-null    object
#  8   Owner          201 non-null    int64
#  9   Car_Age        201 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 15.8+ KB

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014       335000.0       559000.0       27000    Petrol
# 1      sx4  2013       475000.0       954000.0       43000    Diesel
# 2     ciaz  2017       725000.0       985000.0        6900    Petrol
# 3  wagon r  2011       285000.0       415000.0        5200    Petrol
# 4    swift  2014       460000.0       687000.0       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age
# 0      Dealer       Manual      0       11
# 1      Dealer       Manual      0       12
# 2      Dealer       Manual      0        8
# 3      Dealer       Manual      0       14
# 4      Dealer       Manual      0       11

# %%
df=pd.get_dummies(df.drop(columns=['Car_Name','Seller_Type'],axis=1), dtype=int)
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Car_Age  \
# 0  2014       335000.0       559000.0       27000      0       11
# 1  2013       475000.0       954000.0       43000      0       12
# 2  2017       725000.0       985000.0        6900      0        8
# 3  2011       285000.0       415000.0        5200      0       14
# 4  2014       460000.0       687000.0       42450      0       11
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Automatic  \
# 0              0                 0                 1                       0
# 1              0                 1                 0                       0
# 2              0                 0                 1                       0
# 3              0                 0                 1                       0
# 4              0                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# ...

# %%
df.to_csv("../data/processed data/processed_data.csv")
